# %% [markdown]
# ### In this module, we transform the label texts generated using GPT-3 Turbo model  into list of candidate labels
#
# The text generated from the GPT model contains following format:
#
# ```
# {label} : {description}
# ```
#
# To select the labels that best can be used as rate feature for the apps, we use a simple approach in which we simply count the occurrence of the candidate labels.
#
# We use the top five most frequent labels as the final rate features.

# %%
GPT_LABEL_DIR = "../data/gpt labels/"
domains = ["ride", "health", "investing"]

# 6: two to three words labels
# 7: adjective labels
# 9 : NFR labels
indices = {6: "two to three words", 7: "adjective", 9: "NFRs "}

# %%
# 1. get names of all csv files
import os, pandas as pd

domains_labels_dfs = {}

for domain in domains:
    dfs = []
    print("----domain: ", domain, "-----")
    for i in indices.keys():
        print("fetching labels i: ", indices[i])
        label_file = GPT_LABEL_DIR + domain + "_"+str(i)+"_gpt_labels.csv"
        df = pd.read_csv(label_file)
        dfs.append(df)
    domains_labels_dfs[domain] = dfs
# Out:
# ----domain:  ride -----
# fetching labels i:  two to three words
# fetching labels i:  adjective
# fetching labels i:  NFRs
# ----domain:  health -----
# fetching labels i:  two to three words
# fetching labels i:  adjective
# fetching labels i:  NFRs
# ----domain:  investing -----
# fetching labels i:  two to three words
# fetching labels i:  adjective
# fetching labels i:  NFRs

# %%
domains_labels_dfs["ride"][0].head()
# Out:
#                                               params  \
# 0  {'prefix': '\nGenerate minimum of five labels ...
# 1  {'prefix': '\nGenerate minimum of five labels ...
# 2  {'prefix': '\nGenerate minimum of five labels ...
# 3  {'prefix': '\nGenerate minimum of five labels ...
# 4  {'prefix': '\nGenerate minimum of five labels ...
#
#                                                input  \
# 0  i am afairlynew lyftriderand iheardheard that ...
# 1  usually cheaper than uber not cheaper than a c...
# 2  well it's been a roller coaster riding with ly...
# 3  also will it would be nice if there was an opt...
# 4  i hate via they take way to long they take you...
#
#                                               prompt  \
# 0  \nGenerate minimum of five labels (two to thre...
# 1  \nGenerate minimum of five labels (two to thre...
# 2  \nGenerate minimum of five labels (two to thre...
# 3  \nGenerate minimum of five labels (two to thre...
# 4  \nGenerate minimum of five labels (two to thre...
#
#                                    generator choices  \
# 0  [<OpenAIObject at 0x7f0336fe1860> JSON: {\n  "...
# 1  [<OpenAIObject at 0x7f0336ff1d60> JSON: {\n  "...
# 2  [<OpenAIObject at 0x7f0336fe1b30> JSON: {\n  "...
# 3  [<OpenAIObject at 0x7f0336ff1f90> JSON: {\n  "...
# 4  [<OpenAIObject at 0x7f0336fd0590> JSON: {\n  "...
#
#                                               labels
# 0  ['1. Patient Drivers: Lyft drivers are excelle...
# 1  ['1. Cheaper than Uber: Lyft is usually cheape...
# 2  ['1. Unsafe Driver: Reckless driving and dange...
# 3  ['1. Customizable Rides: Option to change time...
# 4  ['1. Poor Customer Service: Long wait times an...

# %%
from collections import Counter
import ast, re
import json
from functools import reduce

def rm_punc(string):
    return re.sub(r'[^\w\s]', "", string)

def str_arr(label_str):
    return label_str.split(",")

def format_labels(labels):
    _labels = []
    for label in labels:
        formatted = label
        if ":" in label:
            formatted = label.split(":")[0]
        elif "-" in label:
            formatted = label.split("-")[0]
        formatted = re.sub(r'[1-9.]', "", formatted) #^a-zA-Z
        formatted = re.sub("and", "", formatted).strip()
        if "," in formatted:
            _labels.extend([rm_punc(item).strip().lower() for item in formatted.split(",")])
        else:
            _labels.append(rm_punc(formatted).strip().lower())
    return list(filter(lambda x: len(x) > 0, _labels))


def format_desc(labels, top_labels):
    label_desc = {}
    for label in labels:
        formatted_label = format_labels([label])[0]
        desc = label
        if ":" in desc:
            desc = desc.split(":")[1]
        elif "-" in desc:
            desc = desc.split("-")[1]
        label_desc[formatted_label] = desc
    return label_desc

def load_label_counter(df, max_num=10, print_top = True):
    df["label_arr"] = df["labels"].apply(lambda x: ast.literal_eval(x))
    df["label_arr_formatted"] = df["label_arr"].apply(lambda x: format_labels(x))
    all_labels = list(reduce(lambda x,y: x+y, df["label_arr_formatted"].tolist()))
    counter = Counter(all_labels)
    if print_top:
        print("\ntop common labels: ", counter.most_common(max_num))
    return df, counter

def load_label_desc(df, output_file):
    df, counter = load_label_counter(df, 10, False)
    top_labels = [item[0] for item in counter.most_common(10)]
    df["label_desc_formatted"] = df["labels"].apply(lambda x: format_desc(ast.literal_eval(x), top_labels))
    print("\nsaving desc to file: ", output_file, "------\n")
    df.to_csv(output_file, header=True, index=False)
    
    all_labels_dict_arr = df["label_desc_formatted"].tolist()
    print("\ndf desc formatted[0]: ", all_labels_dict_arr[0])
    top_label_merged_descs = {}
    for label_desc_dict in all_labels_dict_arr:
        for label, desc in label_desc_dict.items():
            if label in top_labels:
                if label in list(top_label_merged_descs.keys()):
                    top_label_merged_descs[label].append(desc)
                else:
                    top_label_merged_descs[label] = [desc]
    sorted_top_label_merged_descs = {label: top_label_merged_descs[label] for label in top_labels if label in top_label_merged_descs}
    print("\n\nshowing desc for top labels: \n", sorted_top_label_merged_descs)

    top_dict_desc_file = output_file.split(".")[0] + "_top_only.csv"
#     top_desc_df = pd.DataFrame.from_dict(sorted_top_label_merged_descs, orient='index', columns=['Description'])
#     print("\nsaving top descriptions merged to file: ", top_dict_desc_file)
#     top_desc_df.to_csv(top_dict_desc_file, index=False, header=True)
    return df, sorted_top_label_merged_descs

# %%
# TWO TO THREE WORDS LABELS
    
for domain in domains:
    dfs = []
    i = 0
    print("\n\n-------------- DOMAIN: ", domain, "------------------------")
    print("label type: ", indices[i+6])
    df = domains_labels_dfs[domain][i]
    load_label_counter(df)
    print("\n----loading descriptions for top labels: ---\n")
    desc_file = GPT_LABEL_DIR + "desc/" + domain + "_" + str(i+6) + "_gpt_label_desc.csv"
    load_label_desc(df, desc_file)
# Out:
# -------------- DOMAIN:  ride ------------------------
# label type:  two to three words
#
# top common labels:  [('poor customer service', 3), ('safety concerns', 2), ('patient drivers', 1), ('best prices', 1), ('unreliable morning rides', 1), ('clean cars', 1), ('communication issues', 1), ('cheaper than uber', 1), ('more reliable than cabs', 1), ('inconsistent pricing', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/ride_6_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'patient drivers': ' Lyft drivers are excellent and very patient, even when the rider is running late.', 'best prices': ' Lyft still has the best prices per ride compared to competitors.', 'unreliable morning rides': ' Lyft can be unreliable for morning rides due to driver switching and cancellations.', 'clean cars': ' Lyft drivers have clean cars and provide great service.', 'communication issues': ' Lyft needs to improve their app for better communication and messaging with riders.'}
#
#
# showing desc for top labels:
#  {'poor customer service': [' Long wait times and unhelpful representatives', ' Unhelpful and rude conversation with Lyft representatives', ' No way to reach out'], 'safety concerns': [' Hesitant to book due to safety concerns with Uber', ' Driver stole phone during ride'], 'patient drivers': [' Lyft drivers are excellent and very patient, even when the rider is running late.'], 'best prices': [' Lyft still has the best prices per ride compared to competitors.'], 'unreliable morning rides': [' Lyft can be unreliable for morning rides due to driver switching and cancellations.'], 'clean cars': [' Lyft drivers have clean cars and provide great service.'], 'communication issues': [' Lyft needs to improve their app for better communication and messaging with riders.'], 'cheaper than uber': [' Lyft is usually cheaper than Uber.'], 'more reliable than cabs': [' Lyft is more reliable than local cab companies.'], 'inconsistent pricing': [" Lyft's pricing can be inconsistent, especially during inclement weather or busy times."]}
#
#
# -------------- DOMAIN:  health ------------------------
# label type:  two to three words
#
# top common labels:  [('customer service issues', 1), ('religious mismatch', 1), ('limited conversations', 1), ('inappropriate advice', 1), ('experience mismatch', 1), ('calming', 1), ('educational', 1), ('empowering', 1), ('fearreducing', 1), ('supportive', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/health_6_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'customer service issues': ' Difficulty with pricing and communication', 'religious mismatch': ' Paired with a Christian counselor despite being Jewish', 'limited conversations': ' Counselor only asked how the reviewer was doing', 'inappropriate advice': " Counselor gave advice that didn't apply to the situation", 'experience mismatch': ' Paired with inexperienced counselors or men'}
#
#
# showing desc for top labels:
#  {'customer service issues': [' Difficulty with pricing and communication'], 'religious mismatch': [' Paired with a Christian counselor despite being Jewish'], 'limited conversations': [' Counselor only asked how the reviewer was doing'], 'inappropriate advice': [" Counselor gave advice that didn't apply to the situation"], 'experience mismatch': [' Paired with inexperienced counselors or men'], 'calming': [' Helps reduce anxiety'], 'educational': [' Provides information on anxiety'], 'empowering': [' Encourages users to take control of their anxiety'], 'fearreducing': [' Helps users overcome phobias'], 'supportive': [' Provides a sense of community and care']}
#
#
# -------------- DOMAIN:  investing ------------------------
# label type:  two to three words
#
# top common labels:  [('customer service', 2), ('technical issues', 2), ('stock lending', 1), ('automatic investment pie', 1), ('large sums of cash', 1), ('pie customization', 1), ('room for improvement', 1), ('refund issue', 1), ('bank compatibility', 1), ('overdraft fees', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/investing_6_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'stock lending': ' Loan your shares for extra income', 'automatic investment pie': ' Build your own 100 stock profile and split it by %', 'large sums of cash': ' Handle larger sums of cash with a click', 'pie customization': ' Easy to rebalance holdings and customize pies', 'room for improvement': ' Lacks charts, bond information, and overall market % based on industry'}
#
#
# showing desc for top labels:
#  {'customer service': [' No customer service contacted or resolved the matter despite multiple emails.', ' Helpful representatives but powerless to escalate tech issues'], 'technical issues': [' Persistent bugs and login problems', " App doesn't recognize user, password reset not working"], 'stock lending': [' Loan your shares for extra income'], 'automatic investment pie': [' Build your own 100 stock profile and split it by %'], 'large sums of cash': [' Handle larger sums of cash with a click'], 'pie customization': [' Easy to rebalance holdings and customize pies'], 'room for improvement': [' Lacks charts, bond information, and overall market % based on industry'], 'refund issue': [' Gemini refunded the full amount deposited but all currencies were set to 0.00.'], 'bank compatibility': [' Gemini staff notified that the bank was not compatible for trading and an ACH transferable account was needed.'], 'overdraft fees': [" Gemini's mistake caused overdraft and NSF charges on the user's bank account."]}

# %%
# ADJECTIVE LABELS

for domain in domains:
    dfs = []
    i = 1
    print("\n\n----domain: ", domain, "-----")
    print("label type: ", indices[i+6])
    df = domains_labels_dfs[domain][i]
    load_label_counter(df)
    print("\n----loading descriptions for top labels: ---\n")
    desc_file = GPT_LABEL_DIR + "desc/" + domain + "_" + str(i+6) + "_gpt_label_desc.csv"
    load_label_desc(df, desc_file)
# Out:
# ----domain:  ride -----
# label type:  adjective
#
# top common labels:  [('unreliable', 7), ('inconsistent', 3), ('expensive', 3), ('convenient', 2), ('frustrating', 2), ('patient', 1), ('affordable', 1), ('helpful', 1), ('pricey', 1), ('overcharging', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/ride_7_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'patient': ' Drivers are patient and understanding of delays.', 'inconsistent': ' App can switch drivers mid-trip and cause confusion.', 'affordable': ' Prices are competitive and reasonable.', 'helpful': ' Drivers are helpful and accommodating.', 'unreliable': ' App can fail to notify of driver cancellations, causing issues for riders.'}
#
#
# showing desc for top labels:
#  {'unreliable': [' App can fail to notify of driver cancellations, causing issues for riders.', ' Inconsistent and unpredictable service quality', ' App did not work as expected and caused inconvenience.', " App's service is described as unpredictable and inconsistent.", ' App gave different driver, driver never showed, and ride was cancelled.', ' Ride was cancelled and given to someone else, no refund received', ' Credit card payment method is unreliable and leads to unauthorized charges.'], 'inconsistent': [' App can switch drivers mid-trip and cause confusion.', ' Wait times can vary greatly, with some rides arriving within 5-10 minutes and others taking up to an hour.', ' First ride went well, but second ride had issues.'], 'expensive': [' Reviewer complains about unexpected price hikes and additional charges.', ' Charged $50 more than previous ride due to high demand.', ' Lyft rides were twice as expensive as usual'], 'convenient': [' Provides a reliable and timely service, saving time and hassle.', ' Provides USB charging, airplane pillows, and blankets for passengers.'], 'frustrating': [' Reviewer had a difficult time with the app and customer service.', ' Unable to reach customer service and only received automated responses.'], 'patient': [' Drivers are patient and understanding of delays.'], 'affordable': [' Prices are competitive and reasonable.'], 'helpful': [' Drivers are helpful and accommodating.'], 'pricey': [' Generally more expensive than local cab companies, with prices doubling or tripling during peak hours or inclement weather.'], 'overcharging': [' Prices can be excessive and considered price gouging, especially during peak hours or when demand is high.']}
#
#
# ----domain:  health -----
# label type:  adjective
#
# top common labels:  [('frustrating', 4), ('deceptive', 3), ('empowering', 2), ('misleading', 2), ('inaccessible', 2), ('disappointing', 2), ('expensive', 2), ('inexperienced', 1), ('unhelpful', 1), ('insensitive', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/health_7_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'frustrating': ' Difficulty with customer service and counselor matching', 'inexperienced': ' Multiple counselors with only a few years of experience', 'unhelpful': ' Conversations never went beyond surface level', 'insensitive': ' Counselor made inappropriate comments and compared experiences', 'unreliable': ' Subscription cancellation without confirmation or response'}
#
#
# showing desc for top labels:
#  {'frustrating': [' Difficulty with customer service and counselor matching', ' User warns against having a childlike mindset when downloading the app to avoid paying for an unwanted subscription.', ' Difficult to sign up for basic membership or trial', ' Difficulty in finding billing terms and resolving issues.'], 'deceptive': [' App uses marketing tactics to trick young children into downloading and purchasing.', ' Misleading pricing and refund policy', ' Misleading billing practices and lack of transparency.'], 'empowering': [' Encourages users to be brave and take control of their anxiety.', ' Encourages letting thoughts come and go with gentle or effortless focus.'], 'misleading': [" App's name suggests it will help with calmness, but it does not deliver.", ' False claims about AI testing and self-praise'], 'inaccessible': [' All features locked behind expensive subscription', ' No way to contact customer support for refunds'], 'disappointing': [' App fails to deliver on promise of anxiety and sleep assistance', ' Overall negative experience with the app'], 'expensive': [' Despite a student discount, the app is still pricey.', ' Defaulted to a more expensive family plan without consent.'], 'inexperienced': [' Multiple counselors with only a few years of experience'], 'unhelpful': [' Conversations never went beyond surface level'], 'insensitive': [' Counselor made inappropriate comments and compared experiences']}
#
#
# ----domain:  investing -----
# label type:  adjective
#
# top common labels:  [('unreliable', 4), ('deceptive', 3), ('innovative', 2), ('userfriendly', 2), ('disappointing', 2), ('costly', 2), ('frustrating', 2), ('inefficient', 2), ('limited', 1), ('competitive', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/investing_7_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'innovative': ' M1 has a unique investment pie feature that allows users to build their own 100 stock profile and split it by percentage.', 'limited': ' M1 lacks charts to display stock holdings and bond information, as well as the ability to view overall market percentage based on industry.', 'userfriendly': ' M1 makes it easy to rebalance holdings and handle larger sums of cash with just a click.', 'competitive': ' M1 falls short compared to Public in terms of investment options and transaction limits.', 'improvable': ' M1 has room for improvement in areas such as offering fixed rate options, providing more detailed pie charts, and increasing the automatic trade limit.'}
#
#
# showing desc for top labels:
#  {'unreliable': [" Gemini's withdrawal of funds from a non-ACH transferable account, despite previous claims that it was not possible, raises concerns about the app's reliability and trustworthiness.", ' App takes money without explanation or resolution', ' App does not recognize user', ' Withdrawals get stuck in "pending" status without posting'], 'deceptive': [' App tricks users with sophisticated scheme', ' Shows what they want you to see and hides important information', " Misleading and dishonest practices are evident in the app's relationship with Citadel LLC."], 'innovative': [' M1 has a unique investment pie feature that allows users to build their own 100 stock profile and split it by percentage.', ' Offers a unique loyalty plan for users who agree to use drip only.'], 'userfriendly': [' M1 makes it easy to rebalance holdings and handle larger sums of cash with just a click.', ' Simplifies the process of tracking dividend income and portfolio growth.'], 'disappointing': [" Gemini's lack of compatibility with certain bank accounts caused frustration and financial harm to the reviewer.", ' Reviewer had high hopes for the app but was let down by poor customer service.'], 'costly': [" The reviewer incurred numerous fees from their bank due to Gemini's actions, resulting in financial hardship for someone with limited income.", ' App took over half of initial investment without reason or justification'], 'frustrating': [' Reviewer encountered multiple obstacles and unhelpful representatives.', ' Reviewer expresses frustration with ongoing technical issues and lack of resolution.'], 'inefficient': [' Reviewer had to speak with multiple people and still did not receive a resolution.', ' Difficult to reset password and contact support'], 'limited': [' M1 lacks charts to display stock holdings and bond information, as well as the ability to view overall market percentage based on industry.'], 'competitive': [' M1 falls short compared to Public in terms of investment options and transaction limits.']}

# %%
# NFR LABELS

for domain in domains:
    dfs = []
    i = 2
    print("\n\n----domain: ", domain, "-----")
    print("label type: ", indices[9])
    df = domains_labels_dfs[domain][i]
    load_label_counter(df)
    print("\n----loading descriptions for top labels: ---\n")
    desc_file = GPT_LABEL_DIR + "desc/" + domain + "_" + str(9) + "_gpt_label_desc.csv"
    load_label_desc(df, desc_file)
# Out:
# ----domain:  ride -----
# label type:  NFRs
#
# top common labels:  [('reliability', 8), ('security', 5), ('customer support', 5), ('usability', 2), ('accessibility', 2), ('payment', 2), ('user experience', 2), ('transparency', 2), ('customer service', 2), ('performance', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/ride_9_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'reliability': ' The app should ensure that assigned drivers show up on time and do not cancel rides unexpectedly.', 'usability': ' The app should have clear and easy-to-use communication features for riders to contact drivers and vice versa.', 'accessibility': ' The app should be accessible to riders with disabilities, and drivers should be patient and accommodating towards them.', 'performance': ' The app should have fast response times and minimize wait times for riders.', 'security': ' The app should ensure the safety of riders by verifying driver identities and providing secure payment options.'}
#
#
# showing desc for top labels:
#  {'reliability': [' The app should ensure that assigned drivers show up on time and do not cancel rides unexpectedly.', ' The app is more reliable than local cab companies, with wait times usually no more than 5-10 minutes.', ' The app should not log users out or have billing issues that prevent them from using their paid passes.', ' The app should ensure that drivers do not cancel rides after confirmation.', ' The app should ensure that the assigned driver is the same as the one displayed on the app to avoid confusion and inconvenience.', ' The app should ensure that once a ride is booked, it is not cancelled without a valid reason.', ' Company is unreliable and enjoys being a mess', ' Drivers not arriving at correct pick-up points and abandoning passengers'], 'security': [' The app should ensure the safety of riders by verifying driver identities and providing secure payment options.', " App must have measures in place to protect passengers' personal belongings, such as luggage and valuables, from theft or damage.", " The app should have robust security measures to protect users' personal and financial information from theft or misuse.", ' App is not secure and imposes leaving the app page open', ' Incidents of theft and safety concerns during rides'], 'customer support': [' App must have a reliable and responsive customer support system to address any issues or concerns that may arise during a ride.', ' The company should provide timely and effective support to resolve issues with the app or billing.', ' The app should provide prompt and effective customer support to address any issues or concerns that users may have.', ' The app should provide prompt and effective customer support to address any issues or complaints raised by users.', ' Poor response time and lack of assistance from Didi support team'], 'usability': [' The app should have clear and easy-to-use communication features for riders to contact drivers and vice versa.', ' The app should be user-friendly and allow riders to easily contact customer support or call for a ride from a different phone in case of emergencies.'], 'accessibility': [' The app should be accessible to riders with disabilities, and drivers should be patient and accommodating towards them.', ' The app should be accessible to users with disabilities.'], 'payment': [' App must provide transparent and fair pricing for rides, with clear communication of any additional charges or fees.', ' Two credit cards required after four rides, default card declined'], 'user experience': [' The app should be easy to use and not cause frustration for users.', ' The app should provide a seamless and hassle-free experience for users.'], 'transparency': [' The company should clearly communicate any issues with billing or account access to users.', ' The app should clearly communicate any surge pricing or price changes to users before they confirm their ride booking.'], 'customer service': [' The app should have a responsive and helpful customer service team to address user complaints.', ' No way to reach out to Lyft customer service'], 'performance': [' The app should have fast response times and minimize wait times for riders.']}
#
#
# ----domain:  health -----
# label type:  NFRs
#
# top common labels:  [('usability', 5), ('reliability', 4), ('performance', 3), ('security', 3), ('compatibility', 3), ('refund policy', 3), ('pricing', 2), ('user interface', 2), ('accessibility', 2), ('customer support', 2)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/health_9_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'pricing': ' Inconsistent pricing and difficulty in obtaining the same price as others.', 'counselor matching': ' Poor counselor matching, including pairing with a counselor of a different religion.', 'counseling quality': ' Inadequate counseling quality, including lack of progress and inappropriate advice.', 'customer service': ' Poor customer service, including misunderstandings and lack of response.', 'experience level': ' Inconsistent experience level of counselors, including pairing with inexperienced counselors.'}
#
#
# showing desc for top labels:
#  {'usability': [' App is easy to navigate and provides helpful information on anxiety.', ' App should have easy-to-use features for video chat, text, and phone call sessions with therapists.', ' The website should allow for easy sign-up and clear membership options.', ' Provides mindfulness tips and follow-up meditations for a memorable experience', ' App should be designed for novice or beginner students of mindfulness and meditation.'], 'reliability': [' App provides accurate information on anxiety and its effects.', ' App should not have bugs that interrupt voice call sessions, such as the mute/unmute issue reported by the user.', ' Helps users avoid reacting to thoughts and keeping emotions alive', ' App should provide evidence-based results for helping users heal and evolve their self-care.'], 'performance': [' App helps users feel calm and in control of their anxiety.', ' Offers helpful lessons such as observing thoughts and having a daydream sense of mind', ' App should be able to distill scientific and professional jargon into simple language.'], 'security': [' App protects user data and privacy.', ' Protects user data and privacy while using the app', ' App should protect user data and maintain privacy.'], 'compatibility': [' App is compatible with various devices and operating systems.', ' Works seamlessly on different devices and operating systems.', ' App should be compatible with various devices and operating systems.'], 'refund policy': [' App should have a clear refund policy for accidental purchases.', ' The app should have a clear and accessible refund policy.', ' Unsubscribe did not issue a refund.'], 'pricing': [' Inconsistent pricing and difficulty in obtaining the same price as others.', ' The app should have transparent pricing options and not charge users without their consent.'], 'user interface': [' App should have clear and distinct buttons to prevent accidental purchases.', ' Excessive use of emojis and patronizing language'], 'accessibility': [' App should have age restrictions or parental controls to prevent accidental downloads by children.', ' App is not accessible to those with limited financial resources'], 'customer support': [' The app should have accessible customer support for users to contact in case of issues.', ' No non-automated response to inquiries and difficult to get a real support person to help.']}
#
#
# ----domain:  investing -----
# label type:  NFRs
#
# top common labels:  [('security', 5), ('usability', 5), ('performance', 4), ('reliability', 4), ('customer service', 3), ('transparency', 3), ('compatibility', 2), ('accuracy', 2), ('supportability', 2), ('scalability', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/desc/investing_9_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'scalability': ' M1 should be able to handle larger sums of cash with ease.', 'user interface': ' M1 lacks charts to display stock holdings and bond information.', 'performance': ' M1 needs to improve on showing overall market percentage based on industry.', 'flexibility': ' M1 should offer an auto pie sell based on percentage and a fixed rate option for borrowing.', 'customization': ' M1 should allow for comparison of pies and other ETFs, increase the 100 stock limit, and offer 6 automatic trades.'}
#
#
# showing desc for top labels:
#  {'security': [' The app should ensure that user accounts are not vulnerable to fraudulent or unauthorized transactions.', " App must ensure that user's personal information is protected and not linked to incorrect accounts.", ' Two-step authorization is not secure', ' The app should not scam users out of their money and protect their financial information from fraud.', ' Concerns about the safety and protection of personal and financial information'], 'usability': [' App must have a user-friendly interface that allows for easy account creation and stock research.', ' The app must have a functional keyboard that does not switch unexpectedly.', ' App does not allow for easy transfer of funds to other wallets', ' The app should not have hidden fees that significantly reduce the amount of money users have to invest.', ' Difficulty in navigating the app and finding relevant information'], 'performance': [' M1 needs to improve on showing overall market percentage based on industry.', " App takes more money than intended from user's account", ' The app should not have long wait times or boot users out of the queue during live chats with support.', ' App must process transactions in a timely manner'], 'reliability': [' The app must function without breaking watch lists or login issues.', ' Funds are not taken and customer service is unhelpful', ' The app should recognize users and allow them to reset their password and receive email codes promptly.', ' Issues with unauthorized withdrawals and lack of control over finances'], 'customer service': [' The app should have a responsive and effective customer service team to address user concerns and resolve issues in a timely manner.', ' App must have responsive and knowledgeable customer service representatives who can assist with account issues.', ' App must have responsive customer service for transaction issues'], 'transparency': [' The app should provide clear and accurate information about user account activity, including trades and fees, to avoid confusion and prevent unexpected charges.', ' Lack of clear and accessible information for investors', ' The app must provide clear and accurate information about ownership and revenue sources.'], 'compatibility': [' The app should clearly state the requirements for bank accounts that are compatible with trading on the platform.', ' The app must work on multiple platforms, including Google Chrome and Siri.'], 'accuracy': [' App must accurately match user information to prevent errors and confusion.', ' Charts must accurately reflect pricing movements'], 'supportability': [' The app must have responsive and effective customer support for technical issues.', ' The app should have a functional support system that allows users to speak with a human being and resolve issues promptly.'], 'scalability': [' M1 should be able to handle larger sums of cash with ease.']}
