# %% [markdown]
# ### In this module, we transform the label texts generated using GPT-3 Turbo model  into list of candidate labels
#
# The text generated from the GPT model contains following format:
#
# ```
# {label} : {description}
# ```
#
# To select the labels that best can be used as rate feature for the apps, we use a simple approach in which we simply count the occurrence of the candidate labels.
#
# We use the top five most frequent labels as the final rate features.

# %%
GPT_LABEL_DIR = "../data/gpt labels/davinci/"
domains = ["ride", "health", "investing"]

# 6: two to three words labels
# 7: adjective labels
# 9 : NFR labels
# indices = {6: "two to three words", 7: "adjective", 9: "NFRs "} # chatgpt model
indices = {0: "two to three words", 1: "adjective", 2: "NFRs "}

# %%
# 1. get names of all csv files
import os, pandas as pd

domains_labels_dfs = {}

for domain in domains:
    dfs = []
    print("----domain: ", domain, "-----")
    for i in indices.keys():
        print("fetching labels i: ", indices[i])
        label_file = GPT_LABEL_DIR + domain + "_"+str(i)+"_gpt_labels.csv"
        df = pd.read_csv(label_file)
        dfs.append(df)
    domains_labels_dfs[domain] = dfs
# Out:
# ----domain:  ride -----
# fetching labels i:  two to three words
# fetching labels i:  adjective
# fetching labels i:  NFRs
# ----domain:  health -----
# fetching labels i:  two to three words
# fetching labels i:  adjective
# fetching labels i:  NFRs
# ----domain:  investing -----
# fetching labels i:  two to three words
# fetching labels i:  adjective
# fetching labels i:  NFRs

# %%
domains_labels_dfs["ride"][0].head()
# Out:
#                                               params
# 0  {'prefix': '\nGenerate minimum of five labels ...  \
# 1  {'prefix': '\nGenerate minimum of five labels ...
# 2  {'prefix': '\nGenerate minimum of five labels ...
# 3  {'prefix': '\nGenerate minimum of five labels ...
# 4  {'prefix': '\nGenerate minimum of five labels ...
#
#                                                input
# 0  i am afairlynew lyftriderand iheardheard that ...  \
# 1  usually cheaper than uber not cheaper than a c...
# 2  well it's been a roller coaster riding with ly...
# 3  also will it would be nice if there was an opt...
# 4  i hate via they take way to long they take you...
#
#                                               prompt
# 0  \nGenerate minimum of five labels (two to thre...  \
# 1  \nGenerate minimum of five labels (two to thre...
# 2  \nGenerate minimum of five labels (two to thre...
# 3  \nGenerate minimum of five labels (two to thre...
# 4  \nGenerate minimum of five labels (two to thre...
#
#                                    generator choices
# 0  [<OpenAIObject at 0x7fc669beeef0> JSON: {\n  "...  \
# 1  [<OpenAIObject at 0x7fc669c14f40> JSON: {\n  "...
# 2  [<OpenAIObject at 0x7fc669c14900> JSON: {\n  "...
# 3  [<OpenAIObject at 0x7fc669c14c70> JSON: {\n  "...
# 4  [<OpenAIObject at 0x7fc669c14ef0> JSON: {\n  "...
#
#                                               labels
# 0  ['Patient Drivers: Drivers wait patiently and ...
# 1  ['Cheaper than Uber: Lower cost than Uber.', '...
# 2  ['Unsafe Driver: Unsafe driving and reckless b...
# 3  ['Time-Flexibility: Allow changing time of rid...
# 4  ['Inefficient_Service: Poor customer service a...

# %%
from collections import Counter
import ast, re
import json
from functools import reduce

def rm_punc(string):
    return re.sub(r'[^\w\s]', "", string)

def str_arr(label_str):
    return label_str.split(",")

def format_labels(labels):
    _labels = []
    for label in labels:
        formatted = label
        if ":" in label:
            formatted = label.split(":")[0]
        elif "-" in label:
            formatted = label.split("-")[0]
        formatted = re.sub(r'[1-9.]', "", formatted) #^a-zA-Z
        formatted = re.sub("and", "", formatted).strip()
        if "," in formatted:
            _labels.extend([rm_punc(item).strip().lower() for item in formatted.split(",")])
        else:
            _labels.append(rm_punc(formatted).strip().lower())
    return list(filter(lambda x: len(x) > 0, _labels))


def format_desc(labels, top_labels):
    label_desc = {}
    for label in labels:
        format_label_res = format_labels([label])
        if format_label_res:
            formatted_label = format_label_res[0]
            desc = label
            if ":" in desc:
                desc = desc.split(":")[1]
            elif "-" in desc:
                desc = desc.split("-")[1]
            label_desc[formatted_label] = desc
    return label_desc

def load_label_counter(df, max_num=10, print_top = True):
    df["label_arr"] = df["labels"].apply(lambda x: ast.literal_eval(x))
    df["label_arr_formatted"] = df["label_arr"].apply(lambda x: format_labels(x))
    all_labels = list(reduce(lambda x,y: x+y, df["label_arr_formatted"].tolist()))
    counter = Counter(all_labels)
    if print_top:
        print("\ntop common labels: ", counter.most_common(max_num))
    return df, counter

def load_label_desc(df, output_file):
    df, counter = load_label_counter(df, 10, False)
    top_labels = [item[0] for item in counter.most_common(10)]
    df["label_desc_formatted"] = df["labels"].apply(lambda x: format_desc(ast.literal_eval(x), top_labels))
    print("\nsaving desc to file: ", output_file, "------\n")
    df.to_csv(output_file, header=True, index=False)
    
    all_labels_dict_arr = df["label_desc_formatted"].tolist()
    print("\ndf desc formatted[0]: ", all_labels_dict_arr[0])
    top_label_merged_descs = {}
    for label_desc_dict in all_labels_dict_arr:
        for label, desc in label_desc_dict.items():
            if label in top_labels:
                if label in list(top_label_merged_descs.keys()):
                    top_label_merged_descs[label].append(desc)
                else:
                    top_label_merged_descs[label] = [desc]
    sorted_top_label_merged_descs = {label: top_label_merged_descs[label] for label in top_labels if label in top_label_merged_descs}
    print("\n\nshowing desc for top labels: \n", sorted_top_label_merged_descs)

    top_dict_desc_file = output_file.split(".")[0] + "_top_only.csv"
#     top_desc_df = pd.DataFrame.from_dict(sorted_top_label_merged_descs, orient='index', columns=['Description'])
#     print("\nsaving top descriptions merged to file: ", top_dict_desc_file)
#     top_desc_df.to_csv(top_dict_desc_file, index=False, header=True)
    return df, sorted_top_label_merged_descs

# %%
# TWO TO THREE WORDS LABELS
    
for domain in domains:
    dfs = []
    i = 0
    print("\n\n-------------- DOMAIN: ", domain, "------------------------")
#     print("label type: ", indices[i+6]) # chatgpt
    print("label type: ", indices[i])

    df = domains_labels_dfs[domain][i]
    load_label_counter(df)
    print("\n----loading descriptions for top labels: ---\n")
    desc_file = GPT_LABEL_DIR + "desc/" + domain + "_" + str(i) + "_gpt_label_desc.csv"
    load_label_desc(df, desc_file)
# Out:
# -------------- DOMAIN:  ride ------------------------
# label type:  two to three words
#
# top common labels:  [('price gouging', 3), ('unreliable', 2), ('patient drivers', 1), ('good service', 1), ('flexible tips', 1), ('switch drivers', 1), ('cancel rides', 1), ('cheaper than uber', 1), ('reliable', 1), ('wait  save', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/ride_0_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'patient drivers': ' Drivers wait patiently and do not charge extra for late pickups.', 'good service': ' Clean cars and excellent service.', 'flexible tips': ' Drivers are flexible with tips.', 'switch drivers': ' Drivers can switch in the middle of a trip.', 'cancel rides': ' Rides can be cancelled without notice.'}
#
#
# showing desc for top labels:
#  {'price gouging': [' Overcharging excessively.', ' Charging more than advertised.', ' Prices increase during high demand.'], 'unreliable': [' Unreliable service with no customer service.', ' Uber driver cancelled ride.'], 'patient drivers': [' Drivers wait patiently and do not charge extra for late pickups.'], 'good service': [' Clean cars and excellent service.'], 'flexible tips': [' Drivers are flexible with tips.'], 'switch drivers': [' Drivers can switch in the middle of a trip.'], 'cancel rides': [' Rides can be cancelled without notice.'], 'cheaper than uber': [' Lower cost than Uber.'], 'reliable': [' Consistent service.'], 'wait  save': [' 15 minutes before leaving.']}
#
#
# -------------- DOMAIN:  health ------------------------
# label type:  two to three words
#
# top common labels:  [('no refunds', 3), ('mindfulness', 2), ('unhelpful customer service', 1), ('misleading experience', 1), ('unprofessional counselor', 1), ('frustrating system', 1), ('better alternative', 1), ('calming', 1), ('educational', 1), ('empowering', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/health_0_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'unhelpful customer service': ' Unhelpful customer service experience with pricing issues.', 'misleading experience': ' Misleading experience with counselors who lacked experience or were not a good fit.', 'unprofessional counselor': ' Unprofessional counselor who competed with patient and bragged about personal experiences.', 'frustrating system': ' Frustrating system that caused multiple misunderstandings.', 'better alternative': ' Better alternative found with Talkspace.'}
#
#
# showing desc for top labels:
#  {'no refunds': [" Apple's policy of no refunds on digital purchases.", ' No refunds offered for app purchases.', ' Unsubscribe did not issue a refund.'], 'mindfulness': [' Observe thoughts', ' Stress relief'], 'unhelpful customer service': [' Unhelpful customer service experience with pricing issues.'], 'misleading experience': [' Misleading experience with counselors who lacked experience or were not a good fit.'], 'unprofessional counselor': [' Unprofessional counselor who competed with patient and bragged about personal experiences.'], 'frustrating system': [' Frustrating system that caused multiple misunderstandings.'], 'better alternative': [' Better alternative found with Talkspace.'], 'calming': [' Helps reduce anxiety.'], 'educational': [' Provides info on anxiety.'], 'empowering': [' Reminds users they are in control.']}
#
#
# -------------- DOMAIN:  investing ------------------------
# label type:  two to three words
#
# top common labels:  [('stock lending', 1), ('automatic investing', 1), ('research', 1), ('rebalancing', 1), ('charts', 1), ('unresponsive cs', 1), ('fraudulent charge', 1), ('account inactive', 1), ('no value', 1), ('overdraft fees', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/investing_0_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'stock lending': ' Loan shares to short sellers.', 'automatic investing': ' Build own portfolio.', 'research': ' 3rd party info.', 'rebalancing': ' Adjust holdings.', 'charts': ' View stock holdings.'}
#
#
# showing desc for top labels:
#  {'stock lending': [' Loan shares to short sellers.'], 'automatic investing': [' Build own portfolio.'], 'research': [' 3rd party info.'], 'rebalancing': [' Adjust holdings.'], 'charts': [' View stock holdings.'], 'unresponsive cs': [' Unresponsive customer service.'], 'fraudulent charge': [' Unauthorized charge to bank account.'], 'account inactive': [' Account inactive when charge occurred.'], 'no value': [' No value of currency or service provided.'], 'overdraft fees': [' Accruing numerous fees from bank for overdraft.']}

# %%
# ADJECTIVE LABELS

for domain in domains:
    dfs = []
    i = 1
    print("\n\n----domain: ", domain, "-----")
    print("label type: ", indices[i]) # +6 for chatgpt labels
    df = domains_labels_dfs[domain][i]
    load_label_counter(df)
    print("\n----loading descriptions for top labels: ---\n")
    desc_file = GPT_LABEL_DIR + "desc/" + domain + "_" + str(i) + "_gpt_label_desc.csv"
    load_label_desc(df, desc_file)
# Out:
# ----domain:  ride -----
# label type:  adjective
#
# top common labels:  [('unreliable', 4), ('unsafe', 2), ('unresponsive', 2), ('unhelpful', 2), ('expensive', 2), ('reliable', 1), ('affordable', 1), ('flexible', 1), ('unpredictable', 1), ('inconsistent', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/ride_1_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'reliable': ' Drivers are patient and wait for riders without charging extra.', 'affordable': ' Low prices per ride.', 'flexible': ' Drivers are flexible with tips.', 'unpredictable': ' Drivers can switch in the middle of a trip.', 'inconsistent': ' Drivers can cancel without warning.'}
#
#
# showing desc for top labels:
#  {'unreliable': [" concisely describes the app's unreliability in providing service.", ' Unpredictable and unreliable service.', ' Ride cancelled without refund.', ' Unauthorized charges and lack of customer service.'], 'unsafe': [' Unsafe driving and physical assault.', ' Potential for unsafe drivers and situations.'], 'unresponsive': [' Driver unresponsive to calls and requests.', " concisely describes the app's lack of response to customer inquiries."], 'unhelpful': [" concisely describes the app's lack of helpfulness in resolving customer issues.", ' Automated responses and no customer service.'], 'expensive': [' Prices can increase drastically.', ' Lyft rides twice as much as usual.'], 'reliable': [' Drivers are patient and wait for riders without charging extra.'], 'affordable': [' Low prices per ride.'], 'flexible': [' Drivers are flexible with tips.'], 'unpredictable': [' Drivers can switch in the middle of a trip.'], 'inconsistent': [' Drivers can cancel without warning.']}
#
#
# ----domain:  health -----
# label type:  adjective
#
# top common labels:  [('misleading', 3), ('unhelpful', 2), ('compassionate', 2), ('motivating', 2), ('expensive', 2), ('unfair', 2), ('unprofessional', 1), ('discriminatory', 1), ('inconvenient', 1), ('informative', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/health_1_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'unhelpful': " concise description of customer service's lack of assistance", 'unprofessional': " concise description of counselor's inappropriate behavior", 'misleading': ' concise description of false information provided', 'discriminatory': " concise description of counselor's religious bias", 'inconvenient': ' concise description of multiple switches and misunderstandings'}
#
#
# showing desc for top labels:
#  {'misleading': [' concise description of false information provided', ' Deceptive marketing tactics used to target children.', " Billed via Apple Pay but transaction doesn't show on Apple Pay transactions."], 'unhelpful': [" concise description of customer service's lack of assistance", " concise description of the app's unhelpful customer service."], 'compassionate': [' Offers understanding and support for those struggling with anxiety.', ' Cares about helping people heal and evolve their self-care.'], 'motivating': [' Inspires users to be brave and face their fears.', ' Encourages joy and reduces stress.'], 'expensive': [' Yearly subscription costs $75.', " concise description of the app's expensive membership fee."], 'unfair': [' Not providing any free features for people with mental health issues.', ' Subscription defaulted to family plan at 2x the price and unsubscribe did not issue a refund.'], 'unprofessional': [" concise description of counselor's inappropriate behavior"], 'discriminatory': [" concise description of counselor's religious bias"], 'inconvenient': [' concise description of multiple switches and misunderstandings'], 'informative': [' Provides helpful information about anxiety.']}
#
#
# ----domain:  investing -----
# label type:  adjective
#
# top common labels:  [('deceptive', 4), ('misleading', 3), ('robust', 2), ('userfriendly', 2), ('unresponsive', 2), ('unreliable', 2), ('unhelpful', 2), ('inefficient', 2), ('innovative', 1), ('customizable', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/investing_1_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'robust': " concisely describes the app's features and capabilities", 'userfriendly': ' easy to use and navigate', 'innovative': ' offers unique features not found in other investing apps', 'customizable': ' allows users to customize their investments', 'comprehensive': ' provides detailed information on stocks, bonds, and ETFs'}
#
#
# showing desc for top labels:
#  {'deceptive': [' Deceptive practices such as taking more money than expected.', ' Misleading customers with false promises.', ' Deceptive practices and hidden tricks.', ' Misleading customers for personal gain.'], 'misleading': [' Cryptocurrency showed up in portfolio.', ' Charging hidden fees and not disclosing them.', ' Misleading investors by hiding information and not offering modifications.'], 'robust': [" concisely describes the app's features and capabilities", ' concisely describes the selection of stocks and ETFs'], 'userfriendly': [' easy to use and navigate', ' Easy to use interface.'], 'unresponsive': [' No customer service response.', ' Ignoring customer inquiries and requests.'], 'unreliable': [' Unreliable investing app with poor customer service.', ' Unreliable and unable to withdraw money.'], 'unhelpful': [' Unhelpful customer service that does not resolve issues.', ' Unhelpful customer service and irrelevant FAQs.'], 'inefficient': [' Unreliable customer service and slow response times.', ' concisely describes the slow processing of withdrawals'], 'innovative': [' offers unique features not found in other investing apps'], 'customizable': [' allows users to customize their investments']}

# %%
# NFR LABELS

for domain in domains:
    dfs = []
    i = 2
    print("\n\n----domain: ", domain, "-----")
    print("label type: ", indices[i]) # 9 chatgpt
    df = domains_labels_dfs[domain][i]
    load_label_counter(df)
    print("\n----loading descriptions for top labels: ---\n")
    desc_file = GPT_LABEL_DIR + "desc/" + domain + "_" + str(i) + "_gpt_label_desc.csv"
    load_label_desc(df, desc_file)
# Out:
# ----domain:  ride -----
# label type:  NFRs
#
# top common labels:  [('reliability', 4), ('unreliable service', 3), ('security', 2), ('inadequate support', 2), ('customer service', 2), ('timeliness', 1), ('communication', 1), ('driver switching', 1), ('cancellations', 1), ('price gouging', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/ride_2_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'reliability': ' Drivers are patient and reliable, but app can be unreliable.', 'timeliness': ' Drivers are usually on time, but app can be late.', 'communication': ' App has issues with communication and messaging.', 'driver switching': ' App can switch drivers while waiting for pickup.', 'cancellations': ' App can cancel rides while waiting for pickup.'}
#
#
# showing desc for top labels:
#  {'reliability': [' Drivers are patient and reliable, but app can be unreliable.', ' Usually arrives within 5-10 minutes, never more than 15.', ' Ensure consistent and dependable service.', ' Ensuring the app is available and functioning as expected.'], 'unreliable service': [' Ride-hailing app fails to provide reliable service.', ' Service failed to provide a ride after taking payment.', ' Ride-hailing app failed to provide a reliable service, resulting in a cancelled ride and no refund.'], 'security': [' Ensure the safety of users and their belongings.', ' App is not secure and unauthorized charges occur.'], 'inadequate support': [' Poor customer service and inadequate support from the company.', ' Customer service was unable to provide a satisfactory resolution.'], 'customer service': [' Providing customer service support to address user issues.', ' No way to reach out for decent customer service.'], 'timeliness': [' Drivers are usually on time, but app can be late.'], 'communication': [' App has issues with communication and messaging.'], 'driver switching': [' App can switch drivers while waiting for pickup.'], 'cancellations': [' App can cancel rides while waiting for pickup.'], 'price gouging': [' Charging excessively high prices due to customer being stuck.']}
#
#
# ----domain:  health -----
# label type:  NFRs
#
# top common labels:  [('usability', 4), ('unfair pricing', 2), ('customer service', 2), ('cancellation', 2), ('accessibility', 2), ('reliability', 2), ('security', 2), ('support', 2), ('mismatched counselors', 1), ('inappropriate counseling', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/health_2_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'unfair pricing': ' Unfair pricing practices for unemployed customers compared to employed customers.', 'customer service': ' Poor customer service with multiple misunderstandings.', 'mismatched counselors': ' Mismatched counselors with different religious backgrounds and varying levels of experience.', 'inappropriate counseling': ' Inappropriate counseling with counselors bragging about their own experiences.', 'cancellation': ' Cancellation of subscription without confirmation or response.'}
#
#
# showing desc for top labels:
#  {'usability': ['  Description of how user-friendly the app is.', ' Ability to switch therapists and access different communication methods.', ' Poor user experience when attempting to sign up for a basic membership or trial.', ' Ability to understand complex topics and explain them in simple language.'], 'unfair pricing': [' Unfair pricing practices for unemployed customers compared to employed customers.', ' Charging $70/year for an app to help with anxiety and sleep issues.'], 'customer service': [' Poor customer service with multiple misunderstandings.', ' No way to contact customer service for refunds or other inquiries.'], 'cancellation': [' Cancellation of subscription without confirmation or response.', ' No way to cancel via app store, unsubscribe did not issue a refund.'], 'accessibility': [' Description of how easy it is to access the app.', ' Easy to use for novice or beginner students.'], 'reliability': [' Description of how dependable the app is.', ' Proven evidence-based results for helping with self-care.'], 'security': [' Description of how secure the app is.', ' Ensuring data is kept safe and secure.'], 'support': [' Description of how well the app is supported.', ' No non-automated response to inquiries, impossible to get a real support person to help.'], 'mismatched counselors': [' Mismatched counselors with different religious backgrounds and varying levels of experience.'], 'inappropriate counseling': [' Inappropriate counseling with counselors bragging about their own experiences.']}
#
#
# ----domain:  investing -----
# label type:  NFRs
#
# top common labels:  [('usability', 7), ('compatibility', 2), ('reliability', 2), ('security', 2), ('customer service', 2), ('stock lending', 1), ('research', 1), ('limits', 1), ('rebalancing', 1), ('refunds', 1)]
#
# ----loading descriptions for top labels: ---
#
#
# saving desc to file:  ../data/gpt labels/davinci/desc/investing_2_gpt_label_desc.csv ------
#
#
# df desc formatted[0]:  {'usability': ' Easy to use interface for creating and managing investments.', 'stock lending': ' Ability to loan shares to short sellers for extra income.', 'research': ' Access to third-party research for informed decisions.', 'limits': ' No limits on transactions and increased stock options.', 'rebalancing': ' Ability to easily rebalance holdings.'}
#
#
# showing desc for top labels:
#  {'usability': [' Easy to use interface for creating and managing investments.', ' Ensuring the app is easy to use and accessible for disabled users.', ' Poor user experience due to unresolved technical issues.', ' Poor user experience with resetting password and customer support.', ' Poor user experience with limited customization and hard to access information.', ' Poor user experience when withdrawing funds.', ' Ability for users to easily navigate the investing app.'], 'compatibility': [" Ensuring the app is compatible with the user's bank account.", ' Incompatibility with third-party keyboards.'], 'reliability': [' Unreliable application with frequent bugs.', ' Disappearance of funds after fees.'], 'security': [' Potential scam with no human contact.', ' Unreliable security with potential for unauthorized withdrawals.'], 'customer service': [' Unhelpful customer service with no resolution to problems.', ' Poor customer service response time.'], 'stock lending': [' Ability to loan shares to short sellers for extra income.'], 'research': [' Access to third-party research for informed decisions.'], 'limits': [' No limits on transactions and increased stock options.'], 'rebalancing': [' Ability to easily rebalance holdings.'], 'refunds': [' Ensuring the user is refunded for any deposits made.']}
